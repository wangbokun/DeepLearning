# %%
import tensorflow as tf
import numpy as np

# %%
x_data = np.random.rand(100)
y_data =  x_data*0.1 + 0.2


#构造线性模型

b=tf.Variable(0.)
k=tf.Variable(0.)
y=k*x_data + b

#print(x_data)
#print(y_data)

#square 平方
loss = tf.reduce_mean(tf.square(y_data-y))

#定义一个梯度下降方法来训练的优化器
optimizer = tf.train.GradientDescentOptimizer(0.2)


#定义一个最小化代价函数
train = optimizer.minimize(loss)

init = tf.global_variables_initializer()

print(x_data)

with tf.Session() as sess:
    sess.run(init)
    for step in range(201):
        sess.run(train)
        print(step,sess.run([k,b]))
# Out:
# [ 0.16920443  0.49421118  0.75488767  0.47388503  0.76523239  0.33418571
#   0.13657458  0.92717611  0.40521077  0.60080169  0.00233447  0.10306297
#   0.52035819  0.77758143  0.29002156  0.233535    0.14433509  0.77435193
#   0.2851215   0.36496431  0.28840438  0.28712981  0.55690931  0.10653256
#   0.77726569  0.10354065  0.02082671  0.48053147  0.69382577  0.70029918
#   0.39056912  0.15830468  0.41608117  0.45462943  0.07132781  0.36101593
#   0.84918154  0.96795024  0.57750056  0.74641977  0.60412328  0.56493989
#   0.81917629  0.44414487  0.40408029  0.31684814  0.92403617  0.45656258
#   0.843001    0.82538422  0.44699892  0.44194596  0.08619109  0.44771178
#   0.70322321  0.43508581  0.4827392   0.30100795  0.74157956  0.66190517
#   0.03702039  0.78607183  0.7547692   0.25404098  0.39888071  0.54471495
#   0.50030464  0.26143624  0.38070472  0.14027804  0.83218454  0.10754093
#   0.40356982  0.02959375  0.19178086  0.6590185   0.33272561  0.75215582
#   0.89785887  0.86148959  0.11897753  0.22163293  0.59497636  0.83939577
#   0.54555108  0.14773481  0.04320129  0.64506581  0.64758766  0.17470474
#   0.05079983  0.89654076  0.9501195   0.97323812  0.60726331  0.65689948
#   0.68090195  0.59583976  0.64994427  0.24238013]
# 0 [0.050445884, 0.099169947]
# 1 [0.075773969, 0.14900146]
# 2 [0.088483162, 0.174045]
# 3 [0.094852947, 0.18663476]
# 4 [0.098038159, 0.19296755]
# 5 [0.099623777, 0.19615661]
# 6 [0.1004061, 0.19776608]
# 7 [0.10078517, 0.1985818]
# 8 [0.10096199, 0.19899856]
# 9 [0.10103751, 0.19921473]
# 10 [0.10106245, 0.19932994]
# 11 [0.10106228, 0.1993943]
# 12 [0.10104979, 0.19943294]
# 13 [0.10103141, 0.19945852]
# 14 [0.10101034, 0.19947739]
# 15 [0.10098822, 0.19949275]
# 16 [0.10096582, 0.19950621]
# 17 [0.10094356, 0.19951858]
# 18 [0.10092162, 0.19953027]
# 19 [0.1009001, 0.19954149]
# 20 [0.10087903, 0.19955234]
# 21 [0.10085843, 0.19956289]
# 22 [0.1008383, 0.19957317]
# 23 [0.10081863, 0.1995832]
# 24 [0.10079943, 0.19959299]
# 25 [0.10078067, 0.19960254]
# 26 [0.10076236, 0.19961187]
# 27 [0.10074447, 0.19962098]
# 28 [0.10072701, 0.19962987]
# 29 [0.10070994, 0.19963856]
# 30 [0.10069329, 0.19964704]
# 31 [0.10067702, 0.19965532]
# 32 [0.10066114, 0.19966342]
# 33 [0.10064562, 0.19967131]
# 34 [0.10063048, 0.19967902]
# 35 [0.10061569, 0.19968654]
# 36 [0.10060124, 0.1996939]
# 37 [0.10058713, 0.19970109]
# 38 [0.10057335, 0.1997081]
# 39 [0.1005599, 0.19971494]
# 40 [0.10054676, 0.19972163]
# 41 [0.10053393, 0.19972816]
# 42 [0.10052141, 0.19973454]
# 43 [0.10050917, 0.19974077]
# 44 [0.10049723, 0.19974685]
# 45 [0.10048556, 0.19975279]
# 46 [0.10047417, 0.19975859]
# 47 [0.10046305, 0.19976425]
# 48 [0.10045218, 0.19976978]
# 49 [0.10044158, 0.19977519]
# 50 [0.10043121, 0.19978046]
# 51 [0.10042109, 0.19978562]
# 52 [0.10041121, 0.19979064]
# 53 [0.10040157, 0.19979556]
# 54 [0.10039214, 0.19980036]
# 55 [0.10038294, 0.19980504]
# 56 [0.10037395, 0.19980961]
# 57 [0.10036518, 0.19981408]
# 58 [0.10035661, 0.19981845]
# 59 [0.10034824, 0.19982271]
# 60 [0.10034007, 0.19982687]
# 61 [0.10033209, 0.19983093]
# 62 [0.1003243, 0.1998349]
# 63 [0.10031669, 0.19983877]
# 64 [0.10030926, 0.19984256]
# 65 [0.100302, 0.19984625]
# 66 [0.10029492, 0.19984986]
# 67 [0.100288, 0.19985338]
# 68 [0.10028124, 0.19985682]
# 69 [0.10027464, 0.19986017]
# 70 [0.10026819, 0.19986345]
# 71 [0.1002619, 0.19986665]
# 72 [0.10025576, 0.19986978]
# 73 [0.10024976, 0.19987284]
# 74 [0.1002439, 0.19987582]
# 75 [0.10023818, 0.19987874]
# 76 [0.10023259, 0.19988158]
# 77 [0.10022713, 0.19988436]
# 78 [0.10022181, 0.19988707]
# 79 [0.1002166, 0.19988972]
# 80 [0.10021152, 0.19989231]
# 81 [0.10020656, 0.19989485]
# 82 [0.10020171, 0.1998973]
# 83 [0.10019698, 0.19989972]
# 84 [0.10019236, 0.19990207]
# 85 [0.10018785, 0.19990437]
# 86 [0.10018343, 0.19990662]
# 87 [0.10017913, 0.19990881]
# 88 [0.10017493, 0.19991094]
# 89 [0.10017082, 0.19991302]
# 90 [0.10016681, 0.19991507]
# 91 [0.1001629, 0.19991706]
# 92 [0.10015908, 0.19991902]
# 93 [0.10015535, 0.19992091]
# 94 [0.1001517, 0.19992277]
# 95 [0.10014814, 0.19992457]
# 96 [0.10014467, 0.19992635]
# 97 [0.10014127, 0.19992808]
# 98 [0.10013796, 0.19992976]
# 99 [0.10013472, 0.19993141]
# 100 [0.10013156, 0.19993302]
# 101 [0.10012848, 0.19993459]
# 102 [0.10012546, 0.19993612]
# 103 [0.10012252, 0.19993763]
# 104 [0.10011964, 0.19993909]
# 105 [0.10011683, 0.19994052]
# 106 [0.10011409, 0.19994192]
# 107 [0.10011142, 0.19994327]
# 108 [0.1001088, 0.1999446]
# 109 [0.10010625, 0.1999459]
# 110 [0.10010377, 0.19994716]
# 111 [0.10010133, 0.1999484]
# 112 [0.10009895, 0.19994962]
# 113 [0.10009663, 0.1999508]
# 114 [0.10009436, 0.19995196]
# 115 [0.10009215, 0.19995309]
# 116 [0.10008999, 0.1999542]
# 117 [0.10008787, 0.19995527]
# 118 [0.10008581, 0.19995631]
# 119 [0.1000838, 0.19995734]
# 120 [0.10008183, 0.19995834]
# 121 [0.10007991, 0.19995932]
# 122 [0.10007803, 0.19996028]
# 123 [0.1000762, 0.1999612]
# 124 [0.10007441, 0.19996211]
# 125 [0.10007267, 0.199963]
# 126 [0.10007096, 0.19996387]
# 127 [0.1000693, 0.19996472]
# 128 [0.10006768, 0.19996555]
# 129 [0.10006609, 0.19996636]
# 130 [0.10006454, 0.19996715]
# 131 [0.10006303, 0.19996792]
# 132 [0.10006154, 0.19996867]
# 133 [0.1000601, 0.1999694]
# 134 [0.10005869, 0.19997011]
# 135 [0.10005731, 0.19997081]
# 136 [0.10005597, 0.1999715]
# 137 [0.10005466, 0.19997217]
# 138 [0.10005338, 0.19997282]
# 139 [0.10005213, 0.19997346]
# 140 [0.1000509, 0.19997409]
# 141 [0.10004971, 0.1999747]
# 142 [0.10004854, 0.1999753]
# 143 [0.1000474, 0.19997588]
# 144 [0.10004628, 0.19997644]
# 145 [0.1000452, 0.199977]
# 146 [0.10004413, 0.19997753]
# 147 [0.1000431, 0.19997805]
# 148 [0.10004208, 0.19997858]
# 149 [0.10004109, 0.19997908]
# 150 [0.10004013, 0.19997957]
# 151 [0.10003919, 0.19998005]
# 152 [0.10003827, 0.19998051]
# 153 [0.10003737, 0.19998097]
# 154 [0.10003649, 0.19998142]
# 155 [0.10003564, 0.19998185]
# 156 [0.1000348, 0.19998229]
# 157 [0.10003398, 0.1999827]
# 158 [0.10003319, 0.19998311]
# 159 [0.1000324, 0.19998351]
# 160 [0.10003164, 0.19998389]
# 161 [0.1000309, 0.19998427]
# 162 [0.10003018, 0.19998464]
# 163 [0.10002947, 0.199985]
# 164 [0.10002878, 0.19998536]
# 165 [0.1000281, 0.1999857]
# 166 [0.10002743, 0.19998603]
# 167 [0.10002679, 0.19998635]
# 168 [0.10002617, 0.19998668]
# 169 [0.10002555, 0.19998699]
# 170 [0.10002495, 0.19998729]
# 171 [0.10002436, 0.19998759]
# 172 [0.10002379, 0.19998789]
# 173 [0.10002323, 0.19998817]
# 174 [0.10002269, 0.19998845]
# 175 [0.10002215, 0.19998872]
# 176 [0.10002163, 0.19998899]
# 177 [0.10002112, 0.19998924]
# 178 [0.10002063, 0.1999895]
# 179 [0.10002015, 0.19998974]
# 180 [0.10001968, 0.19998997]
# 181 [0.10001922, 0.19999021]
# 182 [0.10001877, 0.19999045]
# 183 [0.10001833, 0.19999067]
# 184 [0.1000179, 0.1999909]
# 185 [0.10001747, 0.19999111]
# 186 [0.10001706, 0.19999132]
# 187 [0.10001666, 0.19999152]
# 188 [0.10001627, 0.19999172]
# 189 [0.10001589, 0.19999191]
# 190 [0.10001551, 0.19999211]
# 191 [0.10001515, 0.19999228]
# 192 [0.10001479, 0.19999246]
# 193 [0.10001445, 0.19999264]
# 194 [0.10001411, 0.19999282]
# 195 [0.10001378, 0.19999298]
# 196 [0.10001346, 0.19999315]
# 197 [0.10001314, 0.19999331]
# 198 [0.10001284, 0.19999346]
# 199 [0.10001254, 0.19999361]
# 200 [0.10001225, 0.19999376]
