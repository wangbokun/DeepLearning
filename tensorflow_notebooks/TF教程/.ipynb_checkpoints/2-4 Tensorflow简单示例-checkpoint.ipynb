# %%
import tensorflow as tf
import numpy as np

# %%
x_data = np.random.rand(100)
y_data =  x_data*0.1 + 0.2


#构造线性模型

b=tf.Variable(0.)
k=tf.Variable(0.)
y=k*x_data + b

#print(x_data)
#print(y_data)

#square 平方
loss = tf.reduce_mean(tf.square(y_data-y))

#定义一个梯度下降方法来训练的优化器
optimizer = tf.train.GradientDescentOptimizer(0.2)


#定义一个最小化代价函数
train = optimizer.minimize(loss)

init = tf.global_variables_initializer()

print(x_data)

with tf.Session() as sess:
    sess.run(init)
    for step in range(201):
        sess.run(train)
        print(step,sess.run([k,b]))
# Out:
# 0 [0.056207418, 0.10090037]
# 1 [0.083228663, 0.14969304]
# 2 [0.096159197, 0.1733211]
# 3 [0.10228852, 0.18479539]
# 4 [0.10513664, 0.19039893]
# 5 [0.10640328, 0.19316578]
# 6 [0.10690916, 0.19456115]
# 7 [0.10705052, 0.19529265]
# 8 [0.10701863, 0.195702]
# 9 [0.10690578, 0.19595428]
# 10 [0.10675646, 0.19612923]
# 11 [0.10659209, 0.19626541]
# 12 [0.10642293, 0.19638148]
# 13 [0.10625388, 0.19648647]
# 14 [0.10608725, 0.19658479]
# 15 [0.10592408, 0.19667861]
# 16 [0.1057648, 0.19676901]
# 17 [0.10560957, 0.19685654]
# 18 [0.10545842, 0.19694151]
# 19 [0.10531127, 0.19702408]
# 20 [0.10516807, 0.19710436]
# 21 [0.10502873, 0.19718248]
# 22 [0.10489313, 0.19725846]
# 23 [0.10476118, 0.1973324]
# 24 [0.10463279, 0.19740433]
# 25 [0.10450787, 0.19747432]
# 26 [0.10438631, 0.19754243]
# 27 [0.10426804, 0.19760869]
# 28 [0.10415295, 0.19767319]
# 29 [0.10404096, 0.19773594]
# 30 [0.10393199, 0.19779699]
# 31 [0.10382596, 0.1978564]
# 32 [0.1037228, 0.1979142]
# 33 [0.10362241, 0.19797044]
# 34 [0.10352473, 0.19802517]
# 35 [0.10342968, 0.19807842]
# 36 [0.1033372, 0.19813024]
# 37 [0.10324721, 0.19818066]
# 38 [0.10315964, 0.19822972]
# 39 [0.10307444, 0.19827744]
# 40 [0.10299154, 0.19832389]
# 41 [0.10291087, 0.19836909]
# 42 [0.10283238, 0.19841307]
# 43 [0.102756, 0.19845587]
# 44 [0.10268168, 0.1984975]
# 45 [0.10260937, 0.19853802]
# 46 [0.102539, 0.19857745]
# 47 [0.10247054, 0.1986158]
# 48 [0.10240392, 0.19865313]
# 49 [0.1023391, 0.19868945]
# 50 [0.10227602, 0.19872479]
# 51 [0.10221464, 0.19875918]
# 52 [0.10215492, 0.19879264]
# 53 [0.10209681, 0.1988252]
# 54 [0.10204027, 0.19885688]
# 55 [0.10198525, 0.19888771]
# 56 [0.10193172, 0.1989177]
# 57 [0.10187963, 0.19894688]
# 58 [0.10182894, 0.19897528]
# 59 [0.10177962, 0.19900291]
# 60 [0.10173164, 0.19902979]
# 61 [0.10168494, 0.19905595]
# 62 [0.10163951, 0.19908141]
# 63 [0.1015953, 0.19910619]
# 64 [0.10155228, 0.19913028]
# 65 [0.10151042, 0.19915374]
# 66 [0.10146969, 0.19917655]
# 67 [0.10143006, 0.19919875]
# 68 [0.1013915, 0.19922036]
# 69 [0.10135398, 0.19924138]
# 70 [0.10131747, 0.19926184]
# 71 [0.10128195, 0.19928175]
# 72 [0.10124738, 0.19930112]
# 73 [0.10121374, 0.19931997]
# 74 [0.10118101, 0.1993383]
# 75 [0.10114916, 0.19935614]
# 76 [0.10111818, 0.1993735]
# 77 [0.10108802, 0.1993904]
# 78 [0.10105868, 0.19940683]
# 79 [0.10103014, 0.19942284]
# 80 [0.10100236, 0.19943839]
# 81 [0.10097533, 0.19945353]
# 82 [0.10094903, 0.19946827]
# 83 [0.10092343, 0.1994826]
# 84 [0.10089853, 0.19949657]
# 85 [0.1008743, 0.19951014]
# 86 [0.10085073, 0.19952334]
# 87 [0.10082779, 0.1995362]
# 88 [0.10080547, 0.19954871]
# 89 [0.10078375, 0.19956088]
# 90 [0.10076261, 0.19957273]
# 91 [0.10074205, 0.19958425]
# 92 [0.10072204, 0.19959545]
# 93 [0.10070257, 0.19960636]
# 94 [0.10068362, 0.19961697]
# 95 [0.10066519, 0.1996273]
# 96 [0.10064726, 0.19963735]
# 97 [0.1006298, 0.19964713]
# 98 [0.10061282, 0.19965665]
# 99 [0.10059629, 0.1996659]
# 100 [0.10058022, 0.19967492]
# 101 [0.10056457, 0.19968368]
# 102 [0.10054935, 0.1996922]
# 103 [0.10053454, 0.1997005]
# 104 [0.10052012, 0.19970858]
# 105 [0.1005061, 0.19971643]
# 106 [0.10049246, 0.19972408]
# 107 [0.10047918, 0.19973153]
# 108 [0.10046626, 0.19973877]
# 109 [0.10045368, 0.19974582]
# 110 [0.10044145, 0.19975267]
# 111 [0.10042954, 0.19975933]
# 112 [0.10041796, 0.19976583]
# 113 [0.10040668, 0.19977215]
# 114 [0.10039572, 0.19977829]
# 115 [0.10038505, 0.19978426]
# 116 [0.10037466, 0.19979008]
# 117 [0.10036456, 0.19979574]
# 118 [0.10035473, 0.19980125]
# 119 [0.10034516, 0.19980662]
# 120 [0.10033586, 0.19981183]
# 121 [0.1003268, 0.1998169]
# 122 [0.10031798, 0.19982183]
# 123 [0.10030941, 0.19982664]
# 124 [0.10030106, 0.19983132]
# 125 [0.10029294, 0.19983587]
# 126 [0.10028505, 0.19984029]
# 127 [0.10027736, 0.1998446]
# 128 [0.10026988, 0.19984879]
# 129 [0.1002626, 0.19985287]
# 130 [0.10025552, 0.19985683]
# 131 [0.10024863, 0.19986069]
# 132 [0.10024192, 0.19986445]
# 133 [0.1002354, 0.19986811]
# 134 [0.10022905, 0.19987167]
# 135 [0.10022288, 0.19987513]
# 136 [0.10021687, 0.1998785]
# 137 [0.10021102, 0.19988178]
# 138 [0.10020532, 0.19988497]
# 139 [0.10019979, 0.19988807]
# 140 [0.1001944, 0.19989108]
# 141 [0.10018916, 0.19989401]
# 142 [0.10018406, 0.19989687]
# 143 [0.1001791, 0.19989966]
# 144 [0.10017427, 0.19990236]
# 145 [0.10016957, 0.19990499]
# 146 [0.10016499, 0.19990756]
# 147 [0.10016055, 0.19991004]
# 148 [0.10015622, 0.19991247]
# 149 [0.10015201, 0.19991483]
# 150 [0.10014791, 0.19991712]
# 151 [0.10014392, 0.19991936]
# 152 [0.10014004, 0.19992153]
# 153 [0.10013627, 0.19992365]
# 154 [0.10013259, 0.19992571]
# 155 [0.10012902, 0.19992772]
# 156 [0.10012554, 0.19992967]
# 157 [0.10012215, 0.19993156]
# 158 [0.10011885, 0.19993341]
# 159 [0.10011565, 0.1999352]
# 160 [0.10011254, 0.19993694]
# 161 [0.1001095, 0.19993864]
# 162 [0.10010655, 0.19994029]
# 163 [0.10010368, 0.1999419]
# 164 [0.10010089, 0.19994347]
# 165 [0.10009817, 0.19994499]
# 166 [0.10009553, 0.19994648]
# 167 [0.10009295, 0.19994792]
# 168 [0.10009044, 0.19994932]
# 169 [0.10008801, 0.1999507]
# 170 [0.10008563, 0.19995202]
# 171 [0.10008332, 0.19995332]
# 172 [0.10008107, 0.19995457]
# 173 [0.10007889, 0.19995579]
# 174 [0.10007676, 0.19995698]
# 175 [0.10007469, 0.19995815]
# 176 [0.10007268, 0.19995928]
# 177 [0.10007072, 0.19996038]
# 178 [0.10006882, 0.19996145]
# 179 [0.10006696, 0.1999625]
# 180 [0.10006515, 0.19996351]
# 181 [0.10006339, 0.19996449]
# 182 [0.10006168, 0.19996545]
# 183 [0.10006002, 0.19996637]
# 184 [0.1000584, 0.19996728]
# 185 [0.10005683, 0.19996816]
# 186 [0.10005529, 0.19996902]
# 187 [0.1000538, 0.19996986]
# 188 [0.10005235, 0.19997066]
# 189 [0.10005094, 0.19997145]
# 190 [0.10004957, 0.19997223]
# 191 [0.10004824, 0.19997297]
# 192 [0.10004693, 0.1999737]
# 193 [0.10004567, 0.19997442]
# 194 [0.10004444, 0.1999751]
# 195 [0.10004324, 0.19997577]
# 196 [0.10004207, 0.19997643]
# 197 [0.10004094, 0.19997707]
# 198 [0.10003984, 0.19997768]
# 199 [0.10003877, 0.19997828]
# 200 [0.10003772, 0.19997886]
